# %%
import numpy as np
import pandas as pd
import nltk

# %%
topic_word = pd.read_csvz("topic_word.txt", delimiter = " ", header = None)

# %%
topic_word.head(4)
# Out:
#        0         1         2         3         4         5
# 0  right  0.000148  0.013105  0.002308  0.002365  0.002102
# 1   like  0.003695  0.032206  0.014054  0.015912  0.013313
# 2  think  0.000266  0.004193  0.000207  0.007498  0.004505
# 3   feel  0.002104  0.003751  0.024140  0.003386  0.007190

# %%
topic_word_1 = topic_word[topic_word.columns[:2]]

# %%
topic_word.sort_values(topic_word.columns[4],ascending=False)
# Out:
#                 0             1             2             3             4  \
# 806            oh  2.393732e-02  3.799717e-03  1.857776e-02  5.056451e-02
# 914            eh  1.334720e-27  4.004653e-35  7.143972e-16  3.073922e-02
# 1520        daddy  3.161975e-05  3.423035e-04  1.131675e-03  2.764324e-02
# 1418           ay  1.025339e-10  3.237186e-08  1.889606e-04  2.396149e-02
# 1348         girl  1.191136e-02  4.425252e-03  3.621714e-03  2.102632e-02
# 907         world  3.398325e-03  1.507885e-02  2.976347e-04  2.061268e-02
# 807          know  3.422290e-02  1.546461e-02  4.962949e-03  1.813884e-02
# 1318         rock  4.424997e-08  1.630998e-03  8.038665e-04  1.676697e-02
# 1            like  3.695387e-03  3.220579e-02  1.405385e-02  1.591162e-02
# 887          take  4.716640e-03  3.629700e-04  3.040953e-03  1.575757e-02
# 1285         wide  2.427569e-06  6.490129e-05  1.286339e-12  1.547395e-02
# 1359        woman  2.813315e-03  1.054720e-04  4.003796e-05  1.457280e-02
# ...
